# %%
import os
import sys
import shutil
sys.path.append('../Module')
folder_path = '../Dataset'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier

from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, f1_score
from sklearn import set_config

from loader_csv import charger_csv
from data_to_csv import df_to_csv
from utils import generate_description
from currency import currency_cleaning
from naics_engineering import naicsEngineering

from Import_csv import import_csv
imported_csv_path = import_csv()

df = pd.read_csv(imported_csv_path)
# Out:
# C:\Users\33679\AppData\Local\Temp\ipykernel_3016\65876671.py:31: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(imported_csv_path)

# %%
generate_description(df)
# Out:
#               feature data_type    null  nulPct  unique  \
# 0       LoanNr_ChkDgt     int64       0    0.00  899164
# 1                Name    object      14    0.00  779583
# 2                City    object      30    0.00   32581
# 3               State    object      14    0.00      51
# 4                 Zip     int64       0    0.00   33611
# 5                Bank    object    1559    0.17    5802
# 6           BankState    object    1566    0.17      56
# 7               NAICS     int64       0    0.00    1312
# 8        ApprovalDate    object       0    0.00    9859
# 9          ApprovalFY    object       0    0.00      70
# 10               Term     int64       0    0.00     412
# 11              NoEmp     int64       0    0.00     599
# 12           NewExist   float64     136    0.02       3
# 13          CreateJob     int64       0    0.00     246
# 14        RetainedJob     int64       0    0.00     358
# 15      FranchiseCode     int64       0    0.00    2768
# 16         UrbanRural     int64       0    0.00       3
# 17          RevLineCr    object    4528    0.50      18
# 18             LowDoc    object    2582    0.29       8
# 19         ChgOffDate    object  736465   81.91    6448
# 20   DisbursementDate    object    2368    0.26    8472
# 21  DisbursementGross    object       0    0.00  118859
# 22       BalanceGross    object       0    0.00      15
# 23         MIS_Status    object    1997    0.22       2
# 24       ChgOffPrinGr    object       0    0.00   83165
# 25             GrAppv    object       0    0.00   22128
# 26           SBA_Appv    object       0    0.00   38326
#
#                                          uniqueSample
# 0   [2206914002, 2284866009, 3330296000, 128233500...
# 1   [DUNKIN DONUTS, Wingmen Associates, LLC, Don M...
# 2   [Fort Walton Beach, ANAHEIM, LOS ANGELES, HORN...
# 3                                [PA, MD, CO, OH, WA]
# 4                 [72335, 47932, 97304, 78404, 11209]
# 5   [PREMIER BANK, WELLS FARGO BANK NATL ASSOC, BA...
# 6                                [CA, DE, OH, SD, TX]
# 7            [812199, 442210, 325998, 531190, 448120]
# 8   [24-Nov-04, 24-Jun-99, 13-Jul-01, 7-Oct-86, 20...
# 9                      [2005, 1998, 2004, 1994, 1995]
# 10                            [75, 240, 84, 180, 123]
# 11                                   [2, 5, 6, 30, 3]
# 12                                         [1.0, 2.0]
# 13                                             [0, 3]
# 14                                             [0, 4]
# 15                                             [1, 0]
# 16                                             [1, 0]
# 17                                             [N, 0]
# 18                                             [N, Y]
# 19                         [nan, 7-Feb-12, 28-Mar-10]
# 20  [14-Jun-06, 31-Oct-90, 31-Mar-03, 31-Jan-95, 3...
# 21  [$121,694.00 , $200,000.00 , $70,000.00 , $2,8...
# 22                                           [$0.00 ]
# 23                                            [P I F]
# 24                 [$0.00 , $427,888.00 , $7,850.00 ]
# 25  [$10,000.00 , $120,000.00 , $120,800.00 , $100...
# 26  [$332,400.00 , $20,000.00 , $104,000.00 , $127...

# %%
df.drop_duplicates(subset=['LoanNr_ChkDgt'], inplace=True)

# %%
df = df[df.NAICS != 0]
df['NAICS'] = df['NAICS'].apply(naicsEngineering)
df.NAICS.value_counts()
# Out:
# NAICS
# 44-45    127251
# 81        72618
# 54        68170
# 31-33     68029
# 72        67600
# 23        66646
# 62        55366
# 42        48743
# 56        32685
# 48-49     22531
# 71        14640
# 53        13632
# 51        11379
# 52         9496
# 11         9005
# 61         6425
# 21         1851
# 22          663
# 55          257
# 92          229
# Name: count, dtype: int64

# %%
df = df[(df.NewExist == 1.0) | (df.NewExist == 2.0)].astype(object)
df.NewExist.value_counts()
# Out:
# NewExist
# 1.0    502830
# 2.0    193520
# Name: count, dtype: int64

# %%
df['GrAppv'] = df['GrAppv'].apply(currency_cleaning).astype(float).astype(int)
df['SBA_Appv'] = df['SBA_Appv'].apply(currency_cleaning).astype(float).astype(int)
df['DisbursementGross'] = df['DisbursementGross'].apply(currency_cleaning).astype(float).astype(int)
df['BalanceGross'] = df['BalanceGross'].apply(currency_cleaning).astype(float).astype(int)
df['ChgOffPrinGr'] = df['ChgOffPrinGr'].apply(currency_cleaning).astype(float)

# %%
mapping = {'0': 'N', '1': 'Y'}
df['RevLineCr'] = df['RevLineCr'].replace(mapping)

valid_values = ['N', 'Y']
df = df[df['RevLineCr'].isin(valid_values)]

df['RevLineCr'].value_counts()
# Out:
# RevLineCr
# N    484187
# Y    195147
# Name: count, dtype: int64

# %%
mapping = {'0': 'N', '1': 'Y'}
df['LowDoc'] = df['LowDoc'].replace(mapping)

valid_values = ['N', 'Y']
df = df[df['LowDoc'].isin(valid_values)]

df['LowDoc'].value_counts()
# Out:
# LowDoc
# N    608823
# Y     66203
# Name: count, dtype: int64

# %%
df['Franchise'] = np.where(df['FranchiseCode'] <= 1, 0, 1)
df = df.drop('FranchiseCode', axis=1)

# %%
df['GrAppv'] = df['GrAppv'].apply(currency_cleaning).astype(float).astype(int)
df['SBA_Appv'] = df['SBA_Appv'].apply(currency_cleaning).astype(float).astype(int)
df['DisbursementGross'] = df['DisbursementGross'].apply(currency_cleaning).astype(float).astype(int)
df['BalanceGross'] = df['BalanceGross'].apply(currency_cleaning).astype(float).astype(int)
df['ChgOffPrinGr'] = df['ChgOffPrinGr'].apply(currency_cleaning).astype(float)

df['Franchise'] = df['Franchise'].astype(object)
df['LowDoc'] = df['LowDoc'].astype(object)
df['RevLineCr'] = df['RevLineCr'].astype(object)
df['NewExist'] = df['NewExist'].astype(object)
df['ApprovalFY'] = df['ApprovalFY'].astype(object)
df['ApprovalDate'] = df['ApprovalDate'].astype(object)
df['NAICS'] = df['NAICS'].astype(object)
df['BankState'] = df['BankState'].astype(object)
df['Bank'] = df['Bank'].astype(object)
df['State'] = df['State'].astype(object)
df['City'] = df['City'].astype(object)

# %%
MIS_Status = pd.get_dummies(df['MIS_Status'], drop_first=True)
df.drop(['MIS_Status'], axis=1, inplace=True)
df = pd.concat([df, MIS_Status], axis=1)
df = df.rename(columns={'P I F': 'Approve'})

# %%
leaking_feature = ['ChgOffPrinGr', 'BalanceGross', 'DisbursementGross', 'DisbursementDate', 'ChgOffDate']
useless_feature = ['Name', 'Zip', 'LoanNr_ChkDgt', 'City', 'State', 'Bank', 'BankState', 'ApprovalDate', 'ApprovalFY']
df = df.drop(leaking_feature, axis=1)
df = df.drop(useless_feature, axis=1)
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (675026, 13)

# %%
generate_description(df)
# Out:
#         feature data_type  null  nulPct  unique  \
# 0         NAICS    object     0     0.0      20
# 1          Term    object     0     0.0     377
# 2         NoEmp    object     0     0.0     499
# 3      NewExist    object     0     0.0       2
# 4     CreateJob    object     0     0.0     216
# 5   RetainedJob    object     0     0.0     323
# 6    UrbanRural    object     0     0.0       3
# 7     RevLineCr    object     0     0.0       2
# 8        LowDoc    object     0     0.0       2
# 9        GrAppv     int32     0     0.0   16880
# 10     SBA_Appv     int32     0     0.0   28240
# 11    Franchise    object     0     0.0       2
# 12      Approve      bool     0     0.0       2
#
#                               uniqueSample
# 0                      [52, 81, 61, 44-45]
# 1                        [84, 240, 42, 64]
# 2                               [1, 7, 15]
# 3                               [2.0, 1.0]
# 4                                   [0, 1]
# 5                                  [0, 10]
# 6                                   [0, 1]
# 7                                   [N, Y]
# 8                                   [N, Y]
# 9   [85000, 15000, 185000, 30000, 1000000]
# 10   [74800, 2500, 100000, 111350, 123750]
# 11                                     [0]
# 12                                  [True]

# %%
df_to_csv(df, folder_path, 'SBA_Cleaned_0.csv')
# Out:
# Le DataFrame a été converti avec succès en fichier CSV : ../Dataset\SBA_Cleaned_0.csv

# %%
df = pd.read_csv(imported_csv_path)
# Out:
# C:\Users\33679\AppData\Local\Temp\ipykernel_3016\3818106162.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(imported_csv_path)

# %%
df.drop_duplicates(subset=['LoanNr_ChkDgt'], inplace=True)

# %%
df = df[df.NAICS != 0]
df['NAICS'] = df['NAICS'].apply(naicsEngineering)

# %%
df = df[(df.NewExist == 1.0) | (df.NewExist == 2.0)]

# %%
df['GrAppv'] = df['GrAppv'].apply(currency_cleaning).astype(float).astype(int)
df['SBA_Appv'] = df['SBA_Appv'].apply(currency_cleaning).astype(float).astype(int)
df['DisbursementGross'] = df['DisbursementGross'].apply(currency_cleaning).astype(float).astype(int)
df['BalanceGross'] = df['BalanceGross'].apply(currency_cleaning).astype(float).astype(int)
df['ChgOffPrinGr'] = df['ChgOffPrinGr'].apply(currency_cleaning).astype(float)

# %%
valid_values = ['N', 'Y']
df = df[df['RevLineCr'].isin(valid_values)]

# %%
valid_values = ['N', 'Y']
df = df[df['LowDoc'].isin(valid_values)]

# %%
df['Franchise'] = np.where(df['FranchiseCode'] <= 1, 0, 1)
df = df.drop('FranchiseCode', axis=1)

# %%
df['GrAppv'] = df['GrAppv'].apply(currency_cleaning).astype(float).astype(int)
df['SBA_Appv'] = df['SBA_Appv'].apply(currency_cleaning).astype(float).astype(int)
df['DisbursementGross'] = df['DisbursementGross'].apply(currency_cleaning).astype(float).astype(int)
df['BalanceGross'] = df['BalanceGross'].apply(currency_cleaning).astype(float).astype(int)
df['ChgOffPrinGr'] = df['ChgOffPrinGr'].apply(currency_cleaning).astype(float)

df['Franchise'] = df['Franchise'].astype(object)
df['LowDoc'] = df['LowDoc'].astype(object)
df['RevLineCr'] = df['RevLineCr'].astype(object)
df['NewExist'] = df['NewExist'].astype(object)
df['ApprovalFY'] = df['ApprovalFY'].astype(object)
df['ApprovalDate'] = df['ApprovalDate'].astype(object)
df['NAICS'] = df['NAICS'].astype(object)
df['BankState'] = df['BankState'].astype(object)
df['Bank'] = df['Bank'].astype(object)
df['State'] = df['State'].astype(object)
df['City'] = df['City'].astype(object)

# %%
MIS_Status = pd.get_dummies(df['MIS_Status'], drop_first=True)
df.drop(['MIS_Status'], axis=1, inplace=True)
df = pd.concat([df, MIS_Status], axis=1)
df = df.rename(columns={'P I F': 'Approve'})

# %%
leaking_feature = ['ChgOffPrinGr', 'BalanceGross', 'DisbursementGross', 'DisbursementDate', 'ChgOffDate']
useless_feature = ['Name', 'Zip', 'LoanNr_ChkDgt', 'City', 'State', 'Bank', 'BankState', 'ApprovalDate', 'ApprovalFY']
df = df.drop(leaking_feature, axis=1)
df = df.drop(useless_feature, axis=1)
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (460816, 13)

# %%
generate_description(df)
# Out:
#         feature data_type  null  nulPct  unique  \
# 0         NAICS    object     0     0.0      20
# 1          Term     int64     0     0.0     373
# 2         NoEmp     int64     0     0.0     432
# 3      NewExist    object     0     0.0       2
# 4     CreateJob     int64     0     0.0     192
# 5   RetainedJob     int64     0     0.0     276
# 6    UrbanRural     int64     0     0.0       3
# 7     RevLineCr    object     0     0.0       2
# 8        LowDoc    object     0     0.0       2
# 9        GrAppv     int32     0     0.0   12824
# 10     SBA_Appv     int32     0     0.0   22309
# 11    Franchise    object     0     0.0       2
# 12      Approve      bool     0     0.0       2
#
#                               uniqueSample
# 0                   [44-45, 48-49, 56, 54]
# 1                           [264, 84, 178]
# 2                                [2, 5, 3]
# 3                                    [1.0]
# 4                                   [0, 5]
# 5                                [6, 1, 0]
# 6                                   [1, 0]
# 7                                   [Y, N]
# 8                                      [N]
# 9     [13000, 50000, 30000, 155000, 15000]
# 10  [15000, 280540, 130200, 68000, 617000]
# 11                                     [0]
# 12                           [True, False]

# %%
df_to_csv(df, folder_path, 'SBA_Cleaned_1.csv')
# Out:
# Le DataFrame a été converti avec succès en fichier CSV : ../Dataset\SBA_Cleaned_1.csv

# %%
df = pd.read_csv(imported_csv_path)
# Out:
# C:\Users\33679\AppData\Local\Temp\ipykernel_3016\3818106162.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(imported_csv_path)

# %%
df.drop_duplicates(subset=['LoanNr_ChkDgt'], inplace=True)

# %%
df = df[df.NAICS != 0]
df['NAICS'] = df['NAICS'].apply(naicsEngineering)

# %%
df = df[(df.NewExist == 1.0) | (df.NewExist == 2.0)]

# %%
df['GrAppv'] = df['GrAppv'].apply(currency_cleaning).astype(float).astype(int)
df['SBA_Appv'] = df['SBA_Appv'].apply(currency_cleaning).astype(float).astype(int)
df['DisbursementGross'] = df['DisbursementGross'].apply(currency_cleaning).astype(float).astype(int)
df['BalanceGross'] = df['BalanceGross'].apply(currency_cleaning).astype(float).astype(int)
df['ChgOffPrinGr'] = df['ChgOffPrinGr'].apply(currency_cleaning).astype(float)

# %%
samples_bad_lol = df[(df['ChgOffDate'].notna())]
df.loc[samples_bad_lol.index, 'MIS_Status'] = samples_bad_lol['MIS_Status'].replace(['P I F', np.nan], 'CHGOFF')

# %%
samples_bad = df[(df['ChgOffPrinGr'].notna()) & ((df['ChgOffPrinGr'] != 0.0) | (df['ChgOffPrinGr'] > 0.0))]
df.loc[samples_bad.index, 'MIS_Status'] = samples_bad['MIS_Status'].replace(['P I F', np.nan], 'CHGOFF')
df['ChgOffPrinGr'] = df['ChgOffPrinGr'].apply(currency_cleaning).fillna(0.0).astype(float).astype(int)

# %%
mapping = {'0': 'N', '1': 'Y'}
df['RevLineCr'] = df['RevLineCr'].replace(mapping)

valid_values = ['N', 'Y']
df = df[df['RevLineCr'].isin(valid_values)]

# %%
mapping = {'0': 'N', '1': 'Y'}
df['LowDoc'] = df['LowDoc'].replace(mapping)

valid_values = ['N', 'Y']
df = df[df['LowDoc'].isin(valid_values)]

# %%
df['Franchise'] = np.where(df['FranchiseCode'] <= 1, 0, 1)
df = df.drop('FranchiseCode', axis=1)

# %%
MIS_Status = pd.get_dummies(df['MIS_Status'], drop_first=True)
df.drop(['MIS_Status'], axis=1, inplace=True)
df = pd.concat([df, MIS_Status], axis=1)
df = df.rename(columns={'P I F': 'Approve'})

# %%
leaking_feature = ['ChgOffPrinGr', 'BalanceGross', 'DisbursementGross', 'DisbursementDate', 'ChgOffDate']
useless_feature = ['Name', 'Zip', 'LoanNr_ChkDgt', 'City', 'State', 'Bank', 'BankState', 'ApprovalDate', 'ApprovalFY']
df = df.drop(leaking_feature, axis=1)
df = df.drop(useless_feature, axis=1)
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (675026, 13)

# %%
generate_description(df)
# Out:
#         feature data_type  null  nulPct  unique  \
# 0         NAICS    object     0     0.0      20
# 1          Term     int64     0     0.0     377
# 2         NoEmp     int64     0     0.0     499
# 3      NewExist   float64     0     0.0       2
# 4     CreateJob     int64     0     0.0     216
# 5   RetainedJob     int64     0     0.0     323
# 6    UrbanRural     int64     0     0.0       3
# 7     RevLineCr    object     0     0.0       2
# 8        LowDoc    object     0     0.0       2
# 9        GrAppv     int32     0     0.0   16880
# 10     SBA_Appv     int32     0     0.0   28240
# 11    Franchise     int32     0     0.0       2
# 12      Approve      bool     0     0.0       2
#
#                               uniqueSample
# 0                             [81, 62, 54]
# 1                       [240, 306, 120, 2]
# 2                        [1, 4, 9, 12, 22]
# 3                               [1.0, 2.0]
# 4                                [2, 0, 3]
# 5                         [9, 6, 24, 2, 0]
# 6                                   [1, 2]
# 7                                   [N, Y]
# 8                                   [N, Y]
# 9   [405131, 1089000, 5000, 25000, 240000]
# 10    [78750, 37500, 72000, 25000, 201000]
# 11                                     [0]
# 12                           [True, False]

# %%
df_to_csv(df, folder_path, 'SBA_Cleaned_2.csv')
# Out:
# Le DataFrame a été converti avec succès en fichier CSV : ../Dataset\SBA_Cleaned_2.csv

# %%
df = pd.read_csv(imported_csv_path)
# Out:
# C:\Users\33679\AppData\Local\Temp\ipykernel_3016\3818106162.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(imported_csv_path)

# %%
generate_description(df)
# Out:
#               feature data_type    null  nulPct  unique  \
# 0       LoanNr_ChkDgt     int64       0    0.00  899164
# 1                Name    object      14    0.00  779583
# 2                City    object      30    0.00   32581
# 3               State    object      14    0.00      51
# 4                 Zip     int64       0    0.00   33611
# 5                Bank    object    1559    0.17    5802
# 6           BankState    object    1566    0.17      56
# 7               NAICS     int64       0    0.00    1312
# 8        ApprovalDate    object       0    0.00    9859
# 9          ApprovalFY    object       0    0.00      70
# 10               Term     int64       0    0.00     412
# 11              NoEmp     int64       0    0.00     599
# 12           NewExist   float64     136    0.02       3
# 13          CreateJob     int64       0    0.00     246
# 14        RetainedJob     int64       0    0.00     358
# 15      FranchiseCode     int64       0    0.00    2768
# 16         UrbanRural     int64       0    0.00       3
# 17          RevLineCr    object    4528    0.50      18
# 18             LowDoc    object    2582    0.29       8
# 19         ChgOffDate    object  736465   81.91    6448
# 20   DisbursementDate    object    2368    0.26    8472
# 21  DisbursementGross    object       0    0.00  118859
# 22       BalanceGross    object       0    0.00      15
# 23         MIS_Status    object    1997    0.22       2
# 24       ChgOffPrinGr    object       0    0.00   83165
# 25             GrAppv    object       0    0.00   22128
# 26           SBA_Appv    object       0    0.00   38326
#
#                                          uniqueSample
# 0   [9065613007, 7378024005, 2279925002, 225147500...
# 1   [THE BODY SPA, ROLLER TRACKERS, INC., INGERICK...
# 2   [KANSAS CITY, TAMARAC, WESTFORD, PINEHURST, OR...
# 3                                        [TX, VA, FL]
# 4                  [80501, 97266, 78108, 91377, 3031]
# 5   [BANK OF AMERICA NATL ASSOC, WILSHIRE BANK, BA...
# 6                                    [CA, DE, OH, IL]
# 7                         [0, 541618, 484121, 445120]
# 8   [30-Sep-02, 25-Feb-99, 4-Feb-05, 18-Sep-97, 17...
# 9                      [1996, 2005, 1990, 1989, 2003]
# 10                                     [240, 84, 120]
# 11                                     [3, 22, 2, 68]
# 12                                         [1.0, 2.0]
# 13                                                [0]
# 14                                       [4, 2, 3, 0]
# 15                                             [0, 1]
# 16                                          [0, 2, 1]
# 17                                          [N, 0, Y]
# 18                                                [N]
# 19                        [nan, 24-May-99, 21-Nov-08]
# 20  [31-Oct-04, 30-Jun-98, 31-Aug-05, 22-Apr-87, 1...
# 21  [$66,845.00 , $84,280.00 , $70,000.00 , $15,00...
# 22                                           [$0.00 ]
# 23                                    [P I F, CHGOFF]
# 24                                           [$0.00 ]
# 25  [$50,000.00 , $149,000.00 , $400,000.00 , $145...
# 26  [$50,000.00 , $855,000.00 , $300,000.00 , $92,...

# %%
df = df.drop_duplicates(subset='LoanNr_ChkDgt')

# %%
is_valide = {1.0, 2.0}
df['NewExist'] = df['NewExist'].isin(is_valide).astype(int).astype(object)

# %%
is_valide = {'0': 'N', '1': 'Y'}
df['RevLineCr'] = df['RevLineCr'].isin(is_valide).astype(object)

# %%
is_valide = {'0': 'N', '1': 'Y'}
df['LowDoc'] = df['LowDoc'].isin(is_valide).astype(object)

# %%
df = df.dropna(subset='NAICS')
df = df[df.NAICS != 0]
df['NAICS'] = df['NAICS'].apply(naicsEngineering)

# %%
mapping = {0: 'unknown', 1: 'urban', 2: 'rural'}
df['UrbanRural'] = df['UrbanRural'].map(mapping).astype(object)

# %%
df['Franchise'] = np.where(df['FranchiseCode'] <= 1, 0, 1).astype(object)
df = df.drop('FranchiseCode', axis=1)

# %%
df['ApprovalDate'] = pd.to_datetime(df['ApprovalDate'], format='%d-%b-%y').dt.strftime('%d-%m-%y').astype(object)

# %%
df['ApprovalDate'].unique()
# Out:
# array(['28-02-97', '07-02-06', '25-03-97', ..., '25-02-97', '26-02-97',
#        '27-02-97'], dtype=object)

# %%
df['ApprovalFY'] = df['ApprovalFY'].astype(str).apply(lambda x: '20' + x[-2:] if int(x[-2:]) >= 0 and int(x[-2:]) <= 27 else '19' + x[-2:]).astype(object)
df['ApprovalFY'].unique()
# Out:
# array(['1997', '2006', '1998', '1999', '2000', '2001', '2003', '2004',
#        '2005', '1984', '2007', '1987', '2008', '1988', '2009', '1989',
#        '1990', '2010', '1991', '2011', '1992', '2002', '2012', '1993',
#        '2013', '1994', '2014', '1995', '1996'], dtype=object)

# %%
df['GrAppv'] = df['GrAppv'].apply(currency_cleaning).astype(float).astype(int)
df['SBA_Appv'] = df['SBA_Appv'].apply(currency_cleaning).astype(float).astype(int)
df['DisbursementGross'] = df['DisbursementGross'].apply(currency_cleaning).astype(float).astype(int)
df['BalanceGross'] = df['BalanceGross'].apply(currency_cleaning).astype(float).astype(int)
df['ChgOffPrinGr'] = df['ChgOffPrinGr'].apply(currency_cleaning).astype(float)

# %%
samples_bad = df[(df['ChgOffPrinGr'].notna()) & (df['ChgOffPrinGr'] != 0.0)]
df.loc[samples_bad.index, 'MIS_Status'] = samples_bad['MIS_Status'].replace(['P I F', np.nan], 'CHGOFF')
df['ChgOffPrinGr'] = df['ChgOffPrinGr'].apply(currency_cleaning).fillna(0.0).astype(float).astype(int)

# %%
samples_bad_lol = df[df['ChgOffDate'].notna()]
df.loc[samples_bad_lol.index, 'MIS_Status'] = samples_bad_lol['MIS_Status'].replace(['P I F', np.nan], 'CHGOFF')

# %%
df['MIS_Status'].value_counts()
# Out:
# MIS_Status
# P I F     550334
# CHGOFF    145335
# Name: count, dtype: int64

# %%
df['Approve'] = df['MIS_Status'].apply(lambda x: 1 if x == 'P I F' else 0).astype(bool)
df.drop(['MIS_Status'], axis=1, inplace=True)

# %%
leaking_feature = ['ChgOffPrinGr', 'BalanceGross', 'DisbursementGross', 'DisbursementDate', 'ChgOffDate']
useless_feature = ['Name', 'Zip', 'LoanNr_ChkDgt']
df = df.drop(leaking_feature, axis=1)
df = df.drop(useless_feature, axis=1)
df = df.dropna()

# %%
generate_description(df)
# Out:
#          feature data_type  null  nulPct  unique  \
# 0           City    object     0     0.0   28860
# 1          State    object     0     0.0      51
# 2           Bank    object     0     0.0    5221
# 3      BankState    object     0     0.0      55
# 4          NAICS    object     0     0.0      20
# 5   ApprovalDate    object     0     0.0    7367
# 6     ApprovalFY    object     0     0.0      29
# 7           Term     int64     0     0.0     378
# 8          NoEmp     int64     0     0.0     502
# 9       NewExist    object     0     0.0       2
# 10     CreateJob     int64     0     0.0     218
# 11   RetainedJob     int64     0     0.0     325
# 12    UrbanRural    object     0     0.0       3
# 13     RevLineCr    object     0     0.0       2
# 14        LowDoc    object     0     0.0       2
# 15        GrAppv     int32     0     0.0   17048
# 16      SBA_Appv     int32     0     0.0   28480
# 17     Franchise    object     0     0.0       2
# 18       Approve      bool     0     0.0       2
#
#                                          uniqueSample
# 0   [WORCESTER, ESCONDIDO, GREAT FALLS, Anderson, ...
# 1                                [OH, AL, FL, MA, MS]
# 2   [U.S. BANK NATIONAL ASSOCIATION, CAPITAL BANK ...
# 3                                [MD, CA, NY, OK, OH]
# 4                                        [56, 23, 54]
# 5   [03-05-02, 16-06-11, 17-10-00, 14-07-05, 25-09...
# 6                      [2007, 2004, 2013, 2003, 2001]
# 7                                   [51, 84, 72, 110]
# 8                                   [20, 4, 3, 2, 11]
# 9                                                 [1]
# 10                                             [0, 2]
# 11                                      [5, 0, 6, 14]
# 12                            [rural, urban, unknown]
# 13                                      [False, True]
# 14                                            [False]
# 15               [36000, 25000, 13000, 414900, 70000]
# 16              [76500, 8925, 1111500, 85000, 100000]
# 17                                                [0]
# 18                                      [True, False]

# %%
df.shape
# Out:
# (696583, 19)

# %%
df_to_csv(df, folder_path, 'SBA_Cleaned_Pure.csv')
# Out:
# Le DataFrame a été converti avec succès en fichier CSV : ../Dataset\SBA_Cleaned_Pure.csv
