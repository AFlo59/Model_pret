# %%
import os
import sys
import gdown
import shutil

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.discriminant_analysis import StandardScaler
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, GradientBoostingClassifier

from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn import set_config

from catboost import CatBoostClassifier

# %%
df = pd.read_csv('SBAcleaned.csv')

df['State'] = df['State'].astype('category')
df['NAICS'] = df['NAICS'].astype('category')
df['Name'] = df['Name'].astype('category')
df['Bank'] = df['Bank'].astype('category')
df['BankState'] = df['BankState'].astype('category')

# %%
y = df['MIS_Status']
X = df.drop('MIS_Status', axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.05, random_state=42, stratify=y)

# %%
numerical_columns_selector = X.select_dtypes(exclude='object').columns
categorical_columns_selector = X.select_dtypes(include='object').columns

numerical_columns = X[numerical_columns_selector]
categorical_columns = X[categorical_columns_selector]

categorical_preprocessor = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

numerical_preprocessor = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

preprocessor = ColumnTransformer(
    transformers=[
        ("nums", numerical_preprocessor, numerical_columns_selector),
        ("cat", categorical_preprocessor, categorical_columns_selector)
    ],
    remainder='passthrough'
)

# %% [markdown]
# # Gradient Boosting

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('gbm', GradientBoostingClassifier())
])

# %%
param_grid = {
    'gbm__n_estimators': [100],  
    'gbm__learning_rate': [0.05, 0.1, 0.2],  
    'gbm__max_depth': [5],
    'gbm__subsample': [0.7, 1.0],
    'gbm__max_features': ['auto', 'sqrt', 'log2'],
    'gbm__loss': ['deviance', 'exponential'],
    'gbm__criterion': ['friedman_mse', 'mse', 'mae'],
    'gbm__init': ['zero', 'random'],
    'gbm__random_state': [42]
}

grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='f1_macro')
grid_search.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 14
#       1 param_grid = {
#       2     'gbm__n_estimators': [100],
#       3     'gbm__learning_rate': [0.05, 0.1, 0.2],
#    (...)
#      10     'gbm__random_state': [42]
#      11 }
#      13 grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='f1_macro')
# ---> 14 grid_search.fit(X_train, y_train)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1527, in GridSearchCV._run_search(self, evaluate_candidates)
#    1525 def _run_search(self, evaluate_candidates):
#    1526     """Search all candidates in param_grid"""
# -> 1527     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:916, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     908 if self.verbose > 0:
#     909     print(
#     910         "Fitting {0} folds for each of {1} candidates,"
#     911         " totalling {2} fits".format(
#     912             n_splits, n_candidates, n_candidates * n_splits
#     913         )
#     914     )
# --> 916 out = parallel(
#     917     delayed(_fit_and_score)(
#     918         clone(base_estimator),
#     919         X,
#     920         y,
#     921         train=train,
#     922         test=test,
#     923         parameters=parameters,
#     924         split_progress=(split_idx, n_splits),
#     925         candidate_progress=(cand_idx, n_candidates),
#     926         **fit_and_score_kwargs,
#     927     )
#     928     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     929         enumerate(candidate_params),
#     930         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     931     )
#     932 )
#     934 if len(out) < 1:
#     935     raise ValueError(
#     936         "No fits were performed. "
#     937         "Was the CV iterator empty? "
#     938         "Were there no candidates?"
#     939     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:129, in _FuncWrapper.__call__(self, *args, **kwargs)
#     127     config = {}
#     128 with config_context(**config):
# --> 129     return self.function(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:890, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     888         estimator.fit(X_train, **fit_params)
#     889     else:
# --> 890         estimator.fit(X_train, y_train, **fit_params)
#     892 except Exception:
#     893     # Note fit time as time until error
#     894     fit_time = time.time() - start_time
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:471, in Pipeline.fit(self, X, y, **params)
#     428 """Fit the model.
#     429
#     430 Fit all the transformers one after the other and sequentially transform the
#    (...)
#     468     Pipeline with fitted steps.
#     469 """
#     470 routed_params = self._check_method_params(method="fit", props=params)
# --> 471 Xt = self._fit(X, y, routed_params)
#     472 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     473     if self._final_estimator != "passthrough":
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:408, in Pipeline._fit(self, X, y, routed_params)
#     406     cloned_transformer = clone(transformer)
#     407 # Fit or load from cache the current transformer
# --> 408 X, fitted_transformer = fit_transform_one_cached(
#     409     cloned_transformer,
#     410     X,
#     411     y,
#     412     None,
#     413     message_clsname="Pipeline",
#     414     message=self._log_message(step_idx),
#     415     params=routed_params[name],
#     416 )
#     417 # Replace the transformer of the step with the fitted
#     418 # transformer. This is necessary when loading the transformer
#     419 # from the cache.
#     420 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/memory.py:349, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     348 def __call__(self, *args, **kwargs):
# --> 349     return self.func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:1303, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1301 with _print_elapsed_time(message_clsname, message):
#    1302     if hasattr(transformer, "fit_transform"):
# -> 1303         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1304     else:
#    1305         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1306             X, **params.get("transform", {})
#    1307         )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py:273, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     271 @wraps(f)
#     272 def wrapped(self, X, *args, **kwargs):
# --> 273     data_to_wrap = f(self, X, *args, **kwargs)
#     274     if isinstance(data_to_wrap, tuple):
#     275         # only wrap the first output for cross decomposition
#     276         return_tuple = (
#     277             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     278             *data_to_wrap[1:],
#     279         )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:914, in ColumnTransformer.fit_transform(self, X, y, **params)
#     911 else:
#     912     routed_params = self._get_empty_routing()
# --> 914 result = self._call_func_on_transformers(
#     915     X,
#     916     y,
#     917     _fit_transform_one,
#     918     column_as_labels=False,
#     919     routed_params=routed_params,
#     920 )
#     922 if not result:
#     923     self._update_fitted_transformers([])
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:823, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     811             extra_args = {}
#     812         jobs.append(
#     813             delayed(func)(
#     814                 transformer=clone(trans) if not fitted else trans,
#    (...)
#     820             )
#     821         )
# --> 823     return Parallel(n_jobs=self.n_jobs)(jobs)
#     825 except ValueError as e:
#     826     if "Expected 2D array, got 1D array instead" in str(e):
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:129, in _FuncWrapper.__call__(self, *args, **kwargs)
#     127     config = {}
#     128 with config_context(**config):
# --> 129     return self.function(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:1303, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1301 with _print_elapsed_time(message_clsname, message):
#    1302     if hasattr(transformer, "fit_transform"):
# -> 1303         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1304     else:
#    1305         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1306             X, **params.get("transform", {})
#    1307         )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:535, in Pipeline.fit_transform(self, X, y, **params)
#     492 """Fit the model and transform with the final estimator.
#     493
#     494 Fit all the transformers one after the other and sequentially transform
#    (...)
#     532     Transformed samples.
#     533 """
#     534 routed_params = self._check_method_params(method="fit_transform", props=params)
# --> 535 Xt = self._fit(X, y, routed_params)
#     537 last_step = self._final_estimator
#     538 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:408, in Pipeline._fit(self, X, y, routed_params)
#     406     cloned_transformer = clone(transformer)
#     407 # Fit or load from cache the current transformer
# --> 408 X, fitted_transformer = fit_transform_one_cached(
#     409     cloned_transformer,
#     410     X,
#     411     y,
#     412     None,
#     413     message_clsname="Pipeline",
#     414     message=self._log_message(step_idx),
#     415     params=routed_params[name],
#     416 )
#     417 # Replace the transformer of the step with the fitted
#     418 # transformer. This is necessary when loading the transformer
#     419 # from the cache.
#     420 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/memory.py:349, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     348 def __call__(self, *args, **kwargs):
# --> 349     return self.func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:1303, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1301 with _print_elapsed_time(message_clsname, message):
#    1302     if hasattr(transformer, "fit_transform"):
# -> 1303         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1304     else:
#    1305         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1306             X, **params.get("transform", {})
#    1307         )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py:273, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     271 @wraps(f)
#     272 def wrapped(self, X, *args, **kwargs):
# --> 273     data_to_wrap = f(self, X, *args, **kwargs)
#     274     if isinstance(data_to_wrap, tuple):
#     275         # only wrap the first output for cross decomposition
#     276         return_tuple = (
#     277             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     278             *data_to_wrap[1:],
#     279         )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1064, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1061     return self.fit(X, **fit_params).transform(X)
#    1062 else:
#    1063     # fit method of arity 2 (supervised transformation)
# -> 1064     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/impute/_base.py:376, in SimpleImputer.fit(self, X, y)
#     358 @_fit_context(prefer_skip_nested_validation=True)
#     359 def fit(self, X, y=None):
#     360     """Fit the imputer on `X`.
#     361
#     362     Parameters
#    (...)
#     374         Fitted estimator.
#     375     """
# --> 376     X = self._validate_input(X, in_fit=True)
#     378     # default fill_value is 0 for numerical input and "missing_value"
#     379     # otherwise
#     380     if self.fill_value is None:
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/impute/_base.py:322, in SimpleImputer._validate_input(self, X, in_fit)
#     319     force_all_finite = True
#     321 try:
# --> 322     X = self._validate_data(
#     323         X,
#     324         reset=in_fit,
#     325         accept_sparse="csc",
#     326         dtype=dtype,
#     327         force_all_finite=force_all_finite,
#     328         copy=self.copy,
#     329     )
#     330 except ValueError as ve:
#     331     if "could not convert" in str(ve):
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:951, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     949         array = xp.astype(array, dtype, copy=False)
#     950     else:
# --> 951         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     952 except ComplexWarning as complex_warning:
#     953     raise ValueError(
#     954         "Complex data not supported\n{}\n".format(array)
#     955     ) from complex_warning
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_array_api.py:521, in _asarray_with_order(array, dtype, order, copy, xp)
#     519     array = numpy.array(array, order=order, dtype=dtype)
#     520 else:
# --> 521     array = numpy.asarray(array, order=order, dtype=dtype)
#     523 # At this point array is a NumPy ndarray. We convert it to an array
#     524 # container that is consistent with the input's namespace.
#     525 return xp.asarray(array)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:2149, in NDFrame.__array__(self, dtype)
#    2148 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2149     values = self._values
#    2150     arr = np.asarray(values, dtype=dtype)
#    2151     if (
#    2152         astype_is_view(values.dtype, arr.dtype)
#    2153         and using_copy_on_write()
#    2154         and self._mgr.is_single_block
#    2155     ):
#    2156         # Check if both conversions can be done without a copy
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1116, in DataFrame._values(self)
#    1114 blocks = mgr.blocks
#    1115 if len(blocks) != 1:
# -> 1116     return ensure_wrapped_if_datetimelike(self.values)
#    1118 arr = blocks[0].values
#    1119 if arr.ndim == 1:
#    1120     # non-2D ExtensionArray
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:12637, in DataFrame.values(self)
#   12563 @property
#   12564 def values(self) -> np.ndarray:
#   12565     """
#   12566     Return a Numpy representation of the DataFrame.
#   12567
#    (...)
#   12635            ['monkey', nan, None]], dtype=object)
#   12636     """
# > 12637     return self._mgr.as_array()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:1693, in BlockManager.as_array(self, dtype, copy, na_value)
#    1691         arr.flags.writeable = False
#    1692 else:
# -> 1693     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1694     # The underlying data was copied within _interleave, so no need
#    1695     # to further copy if copy=True or setting na_value
#    1697 if na_value is lib.no_default:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:1736, in BlockManager._interleave(self, dtype, na_value)
#    1734         arr = blk.get_values(dtype)
#    1735         result[rl.indexer] = arr
# -> 1736         itemmask[rl.indexer] = 1
#    1737     return result
#    1739 for blk in self.blocks:
#
# KeyboardInterrupt:

# %%
print(f"Best hyperparameters : {grid_search.best_params_}")

print(f"Best accuracy : {grid_search.best_score_}")
# Out:
# Best hyperparameters : {'gbm__criterion': 'friedman_mse', 'gbm__init': 'zero', 'gbm__learning_rate': 0.2, 'gbm__loss': 'exponential', 'gbm__max_depth': 5, 'gbm__max_features': 'sqrt', 'gbm__n_estimators': 100, 'gbm__random_state': 42, 'gbm__subsample': 0.7}
# Best accuracy : 0.8528162005184452

# %%
best_model = grid_search.best_estimator_

predictions = best_model.predict(X_test)

# %%
f1_macro = f1_score(y_test, predictions, average='macro')

print(f"Score F1 : {f1_macro}")
# Out:
# Score F1 : 0.8511125837608076

# %% [markdown]
# # Catboost Classifier

# %%
cat_features = ['State','NAICS','Name', 'City','Bank','BankState']

model = CatBoostClassifier(cat_features=cat_features)

model.fit(X_train, y_train)
# Out:
# Learning rate set to 0.123656
# 0:	learn: 0.5641357	total: 497ms	remaining: 8m 16s
# 1:	learn: 0.4623802	total: 696ms	remaining: 5m 47s
# 2:	learn: 0.3855870	total: 848ms	remaining: 4m 41s
# 3:	learn: 0.3411232	total: 1.07s	remaining: 4m 26s
# 4:	learn: 0.3064233	total: 1.26s	remaining: 4m 10s
# 5:	learn: 0.2850050	total: 1.5s	remaining: 4m 7s
# 6:	learn: 0.2633442	total: 1.74s	remaining: 4m 7s
# 7:	learn: 0.2514004	total: 2.01s	remaining: 4m 9s
# 8:	learn: 0.2386960	total: 2.23s	remaining: 4m 5s
# 9:	learn: 0.2303320	total: 2.39s	remaining: 3m 56s
# 10:	learn: 0.2218997	total: 2.55s	remaining: 3m 49s
# 11:	learn: 0.2170014	total: 2.67s	remaining: 3m 39s
# 12:	learn: 0.2089670	total: 2.82s	remaining: 3m 34s
# 13:	learn: 0.2043733	total: 2.96s	remaining: 3m 28s
# 14:	learn: 0.2002004	total: 3.11s	remaining: 3m 24s
# 15:	learn: 0.1963989	total: 3.23s	remaining: 3m 18s
# 16:	learn: 0.1930659	total: 3.35s	remaining: 3m 13s
# 17:	learn: 0.1904397	total: 3.52s	remaining: 3m 11s
# 18:	learn: 0.1885115	total: 3.67s	remaining: 3m 9s
# 19:	learn: 0.1858117	total: 3.82s	remaining: 3m 7s
# 20:	learn: 0.1840517	total: 3.96s	remaining: 3m 4s
# 21:	learn: 0.1816385	total: 4.09s	remaining: 3m 1s
# 22:	learn: 0.1796306	total: 4.27s	remaining: 3m 1s
# 23:	learn: 0.1769878	total: 4.42s	remaining: 2m 59s
# 24:	learn: 0.1751690	total: 4.58s	remaining: 2m 58s
# 25:	learn: 0.1739193	total: 4.81s	remaining: 3m
# 26:	learn: 0.1727572	total: 4.95s	remaining: 2m 58s
# 27:	learn: 0.1716157	total: 5.11s	remaining: 2m 57s
# 28:	learn: 0.1706168	total: 5.28s	remaining: 2m 56s
# 29:	learn: 0.1697405	total: 5.51s	remaining: 2m 58s
# 30:	learn: 0.1682019	total: 5.82s	remaining: 3m 1s
# 31:	learn: 0.1668652	total: 6s	remaining: 3m 1s
# 32:	learn: 0.1650321	total: 6.19s	remaining: 3m 1s
# 33:	learn: 0.1637848	total: 6.35s	remaining: 3m
# 34:	learn: 0.1623044	total: 6.52s	remaining: 2m 59s
# 35:	learn: 0.1612962	total: 6.77s	remaining: 3m 1s
# 36:	learn: 0.1602212	total: 6.97s	remaining: 3m 1s
# 37:	learn: 0.1590661	total: 7.13s	remaining: 3m
# 38:	learn: 0.1584402	total: 7.27s	remaining: 2m 59s
# 409:	learn: 0.1043258	total: 59.6s	remaining: 1m 25s
# 410:	learn: 0.1042888	total: 59.7s	remaining: 1m 25s
# 411:	learn: 0.1042651	total: 59.9s	remaining: 1m 25s
# 412:	learn: 0.1042340	total: 1m	remaining: 1m 25s
# 413:	learn: 0.1042103	total: 1m	remaining: 1m 25s
# 414:	learn: 0.1041838	total: 1m	remaining: 1m 25s
# 415:	learn: 0.1041577	total: 1m	remaining: 1m 24s
# 416:	learn: 0.1041282	total: 1m	remaining: 1m 24s
# 417:	learn: 0.1041089	total: 1m	remaining: 1m 24s
# 418:	learn: 0.1040911	total: 1m	remaining: 1m 24s
# 419:	learn: 0.1040698	total: 1m	remaining: 1m 24s
# 420:	learn: 0.1040388	total: 1m 1s	remaining: 1m 24s
# 421:	learn: 0.1039877	total: 1m 1s	remaining: 1m 23s
# 422:	learn: 0.1039685	total: 1m 1s	remaining: 1m 23s
# 423:	learn: 0.1039426	total: 1m 1s	remaining: 1m 23s
# 424:	learn: 0.1038463	total: 1m 1s	remaining: 1m 23s
# 425:	learn: 0.1038166	total: 1m 1s	remaining: 1m 23s
# 426:	learn: 0.1037892	total: 1m 1s	remaining: 1m 23s
# 427:	learn: 0.1037043	total: 1m 2s	remaining: 1m 22s
# 428:	learn: 0.1036988	total: 1m 2s	remaining: 1m 22s
# 429:	learn: 0.1036420	total: 1m 2s	remaining: 1m 22s
# 430:	learn: 0.1036375	total: 1m 2s	remaining: 1m 22s
# 431:	learn: 0.1036258	total: 1m 2s	remaining: 1m 22s
# 432:	learn: 0.1036032	total: 1m 2s	remaining: 1m 22s
# 433:	learn: 0.1035637	total: 1m 2s	remaining: 1m 22s
# 434:	learn: 0.1035089	total: 1m 3s	remaining: 1m 21s
# 435:	learn: 0.1034656	total: 1m 3s	remaining: 1m 21s
# 436:	learn: 0.1034473	total: 1m 3s	remaining: 1m 21s
# 437:	learn: 0.1034283	total: 1m 3s	remaining: 1m 21s
# 438:	learn: 0.1034092	total: 1m 3s	remaining: 1m 21s
# 439:	learn: 0.1033650	total: 1m 3s	remaining: 1m 21s
# 440:	learn: 0.1033469	total: 1m 3s	remaining: 1m 20s
# 441:	learn: 0.1033257	total: 1m 3s	remaining: 1m 20s
# 442:	learn: 0.1033186	total: 1m 4s	remaining: 1m 20s
# 443:	learn: 0.1032733	total: 1m 4s	remaining: 1m 20s
# 444:	learn: 0.1032375	total: 1m 4s	remaining: 1m 20s
# 445:	learn: 0.1032158	total: 1m 4s	remaining: 1m 20s
# 446:	learn: 0.1032051	total: 1m 4s	remaining: 1m 20s
# 447:	learn: 0.1031895	total: 1m 4s	remaining: 1m 19s
# 448:	learn: 0.1031425	total: 1m 4s	remaining: 1m 19s
# 449:	learn: 0.1031280	total: 1m 5s	remaining: 1m 19s
# 450:	learn: 0.1030733	total: 1m 5s	remaining: 1m 19s
# 451:	learn: 0.1029889	total: 1m 5s	remaining: 1m 19s
# 452:	learn: 0.1029538	total: 1m 5s	remaining: 1m 19s
# 453:	learn: 0.1029405	total: 1m 5s	remaining: 1m 18s
# 454:	learn: 0.1028702	total: 1m 5s	remaining: 1m 18s
# 455:	learn: 0.1028442	total: 1m 5s	remaining: 1m 18s
# 456:	learn: 0.1028054	total: 1m 6s	remaining: 1m 18s
# 457:	learn: 0.1027750	total: 1m 6s	remaining: 1m 18s
# 458:	learn: 0.1027498	total: 1m 6s	remaining: 1m 18s
# 459:	learn: 0.1027106	total: 1m 6s	remaining: 1m 17s
# 460:	learn: 0.1026849	total: 1m 6s	remaining: 1m 17s
# 461:	learn: 0.1026760	total: 1m 6s	remaining: 1m 17s
# 462:	learn: 0.1026482	total: 1m 6s	remaining: 1m 17s
# 463:	learn: 0.1026097	total: 1m 6s	remaining: 1m 17s
# 464:	learn: 0.1025925	total: 1m 7s	remaining: 1m 17s
# 465:	learn: 0.1025288	total: 1m 7s	remaining: 1m 17s
# 466:	learn: 0.1025157	total: 1m 7s	remaining: 1m 16s
# 467:	learn: 0.1024853	total: 1m 7s	remaining: 1m 16s
# 468:	learn: 0.1024706	total: 1m 7s	remaining: 1m 16s
# 469:	learn: 0.1024028	total: 1m 7s	remaining: 1m 16s
# 470:	learn: 0.1023731	total: 1m 7s	remaining: 1m 16s
# 471:	learn: 0.1023344	total: 1m 8s	remaining: 1m 16s
# 472:	learn: 0.1023207	total: 1m 8s	remaining: 1m 15s
# 473:	learn: 0.1023124	total: 1m 8s	remaining: 1m 15s
# 474:	learn: 0.1022910	total: 1m 8s	remaining: 1m 15s
# 475:	learn: 0.1022654	total: 1m 8s	remaining: 1m 15s
# 476:	learn: 0.1022438	total: 1m 8s	remaining: 1m 15s
# 477:	learn: 0.1022281	total: 1m 8s	remaining: 1m 15s
# 478:	learn: 0.1021910	total: 1m 8s	remaining: 1m 14s
# 479:	learn: 0.1021429	total: 1m 9s	remaining: 1m 14s
# 480:	learn: 0.1021076	total: 1m 9s	remaining: 1m 14s
# 481:	learn: 0.1020972	total: 1m 9s	remaining: 1m 14s
# 482:	learn: 0.1020421	total: 1m 9s	remaining: 1m 14s
# 483:	learn: 0.1020158	total: 1m 9s	remaining: 1m 14s
# 484:	learn: 0.1019967	total: 1m 9s	remaining: 1m 14s
# 485:	learn: 0.1018864	total: 1m 9s	remaining: 1m 13s
# 486:	learn: 0.1018497	total: 1m 10s	remaining: 1m 13s
# 487:	learn: 0.1018269	total: 1m 10s	remaining: 1m 13s
# 488:	learn: 0.1018073	total: 1m 10s	remaining: 1m 13s
# 489:	learn: 0.1017920	total: 1m 10s	remaining: 1m 13s
# 490:	learn: 0.1017704	total: 1m 10s	remaining: 1m 13s
# 491:	learn: 0.1017468	total: 1m 10s	remaining: 1m 12s
# 492:	learn: 0.1017292	total: 1m 10s	remaining: 1m 12s
# 493:	learn: 0.1017060	total: 1m 10s	remaining: 1m 12s
# 494:	learn: 0.1016858	total: 1m 11s	remaining: 1m 12s
# 495:	learn: 0.1016857	total: 1m 11s	remaining: 1m 12s
# 496:	learn: 0.1016767	total: 1m 11s	remaining: 1m 12s
# 497:	learn: 0.1016664	total: 1m 11s	remaining: 1m 12s
# 498:	learn: 0.1016554	total: 1m 11s	remaining: 1m 11s
# 499:	learn: 0.1016382	total: 1m 11s	remaining: 1m 11s
# 500:	learn: 0.1016079	total: 1m 11s	remaining: 1m 11s
# 501:	learn: 0.1015874	total: 1m 12s	remaining: 1m 11s
# 502:	learn: 0.1015708	total: 1m 12s	remaining: 1m 11s
# 503:	learn: 0.1015564	total: 1m 12s	remaining: 1m 11s
# 504:	learn: 0.1015400	total: 1m 12s	remaining: 1m 10s
# 505:	learn: 0.1014780	total: 1m 12s	remaining: 1m 10s
# 506:	learn: 0.1014748	total: 1m 12s	remaining: 1m 10s
# 507:	learn: 0.1014690	total: 1m 12s	remaining: 1m 10s
# 508:	learn: 0.1014540	total: 1m 12s	remaining: 1m 10s
# 509:	learn: 0.1014286	total: 1m 13s	remaining: 1m 10s
# 510:	learn: 0.1014106	total: 1m 13s	remaining: 1m 10s
# 511:	learn: 0.1013724	total: 1m 13s	remaining: 1m 9s
# 512:	learn: 0.1013514	total: 1m 13s	remaining: 1m 9s
# 513:	learn: 0.1013294	total: 1m 13s	remaining: 1m 9s
# 514:	learn: 0.1012752	total: 1m 13s	remaining: 1m 9s
# 515:	learn: 0.1012459	total: 1m 13s	remaining: 1m 9s
# 516:	learn: 0.1012320	total: 1m 14s	remaining: 1m 9s
# 517:	learn: 0.1011975	total: 1m 14s	remaining: 1m 8s
# 518:	learn: 0.1011944	total: 1m 14s	remaining: 1m 8s
# 519:	learn: 0.1011798	total: 1m 14s	remaining: 1m 8s
# 520:	learn: 0.1011707	total: 1m 14s	remaining: 1m 8s
# 521:	learn: 0.1011620	total: 1m 14s	remaining: 1m 8s
# 522:	learn: 0.1011435	total: 1m 14s	remaining: 1m 8s
# 523:	learn: 0.1011205	total: 1m 14s	remaining: 1m 8s
# 524:	learn: 0.1010893	total: 1m 15s	remaining: 1m 7s
# 525:	learn: 0.1010504	total: 1m 15s	remaining: 1m 7s
# 526:	learn: 0.1010159	total: 1m 15s	remaining: 1m 7s
# 527:	learn: 0.1010000	total: 1m 15s	remaining: 1m 7s
# 528:	learn: 0.1009648	total: 1m 15s	remaining: 1m 7s
# 529:	learn: 0.1009239	total: 1m 15s	remaining: 1m 7s
# 530:	learn: 0.1009126	total: 1m 15s	remaining: 1m 7s
# 531:	learn: 0.1008974	total: 1m 16s	remaining: 1m 6s
# 532:	learn: 0.1008834	total: 1m 16s	remaining: 1m 6s
# 533:	learn: 0.1008638	total: 1m 16s	remaining: 1m 6s
# 534:	learn: 0.1008554	total: 1m 16s	remaining: 1m 6s
# 535:	learn: 0.1008308	total: 1m 16s	remaining: 1m 6s
# 536:	learn: 0.1008205	total: 1m 16s	remaining: 1m 6s
# 537:	learn: 0.1007328	total: 1m 16s	remaining: 1m 6s
# 538:	learn: 0.1006880	total: 1m 17s	remaining: 1m 5s
# 539:	learn: 0.1006767	total: 1m 17s	remaining: 1m 5s
# 540:	learn: 0.1006513	total: 1m 17s	remaining: 1m 5s
# 541:	learn: 0.1006492	total: 1m 17s	remaining: 1m 5s
# 542:	learn: 0.1006396	total: 1m 17s	remaining: 1m 5s
# 543:	learn: 0.1006227	total: 1m 17s	remaining: 1m 5s
# 544:	learn: 0.1005973	total: 1m 17s	remaining: 1m 5s
# 545:	learn: 0.1005700	total: 1m 18s	remaining: 1m 4s
# 546:	learn: 0.1005177	total: 1m 18s	remaining: 1m 4s
# 547:	learn: 0.1004899	total: 1m 18s	remaining: 1m 4s
# 548:	learn: 0.1004712	total: 1m 18s	remaining: 1m 4s
# 549:	learn: 0.1004427	total: 1m 18s	remaining: 1m 4s
# 550:	learn: 0.1004346	total: 1m 18s	remaining: 1m 4s
# 551:	learn: 0.1004295	total: 1m 18s	remaining: 1m 4s
# 552:	learn: 0.1003935	total: 1m 18s	remaining: 1m 3s
# 553:	learn: 0.1003729	total: 1m 19s	remaining: 1m 3s
# 554:	learn: 0.1003482	total: 1m 19s	remaining: 1m 3s
# 555:	learn: 0.1003259	total: 1m 19s	remaining: 1m 3s
# 556:	learn: 0.1003258	total: 1m 19s	remaining: 1m 3s
# 557:	learn: 0.1002954	total: 1m 19s	remaining: 1m 3s
# 558:	learn: 0.1002781	total: 1m 19s	remaining: 1m 2s
# 559:	learn: 0.1002529	total: 1m 19s	remaining: 1m 2s
# 560:	learn: 0.1002220	total: 1m 20s	remaining: 1m 2s
# 561:	learn: 0.1002126	total: 1m 20s	remaining: 1m 2s
# 562:	learn: 0.1001825	total: 1m 20s	remaining: 1m 2s
# 563:	learn: 0.1001655	total: 1m 20s	remaining: 1m 2s
# 564:	learn: 0.1001555	total: 1m 20s	remaining: 1m 2s
# 565:	learn: 0.1001309	total: 1m 20s	remaining: 1m 1s
# 566:	learn: 0.1001184	total: 1m 20s	remaining: 1m 1s
# 567:	learn: 0.1001129	total: 1m 21s	remaining: 1m 1s
# 568:	learn: 0.1000901	total: 1m 21s	remaining: 1m 1s
# 569:	learn: 0.1000760	total: 1m 21s	remaining: 1m 1s
# 570:	learn: 0.1000451	total: 1m 21s	remaining: 1m 1s
# 571:	learn: 0.1000377	total: 1m 21s	remaining: 1m 1s
# 572:	learn: 0.1000268	total: 1m 21s	remaining: 1m
# 573:	learn: 0.1000014	total: 1m 21s	remaining: 1m
# 574:	learn: 0.0999817	total: 1m 22s	remaining: 1m
# 575:	learn: 0.0999577	total: 1m 22s	remaining: 1m
# 576:	learn: 0.0999356	total: 1m 22s	remaining: 1m
# 577:	learn: 0.0999205	total: 1m 22s	remaining: 1m
# 578:	learn: 0.0998917	total: 1m 22s	remaining: 1m
# 579:	learn: 0.0998767	total: 1m 22s	remaining: 59.9s
# 580:	learn: 0.0998638	total: 1m 22s	remaining: 59.8s
# 581:	learn: 0.0998442	total: 1m 23s	remaining: 59.6s
# 582:	learn: 0.0998396	total: 1m 23s	remaining: 59.5s
# 583:	learn: 0.0998246	total: 1m 23s	remaining: 59.3s
# 584:	learn: 0.0997982	total: 1m 23s	remaining: 59.2s
# 585:	learn: 0.0997725	total: 1m 23s	remaining: 59s
# 586:	learn: 0.0997516	total: 1m 23s	remaining: 58.9s
# 587:	learn: 0.0996517	total: 1m 23s	remaining: 58.7s
# 588:	learn: 0.0996257	total: 1m 23s	remaining: 58.6s
# 589:	learn: 0.0996072	total: 1m 24s	remaining: 58.5s
# 590:	learn: 0.0995918	total: 1m 24s	remaining: 58.3s
# 591:	learn: 0.0995730	total: 1m 24s	remaining: 58.2s
# 592:	learn: 0.0995318	total: 1m 24s	remaining: 58s
# 593:	learn: 0.0995234	total: 1m 24s	remaining: 57.9s
# 594:	learn: 0.0994901	total: 1m 24s	remaining: 57.8s
# 595:	learn: 0.0994777	total: 1m 25s	remaining: 57.6s
# 596:	learn: 0.0994498	total: 1m 25s	remaining: 57.5s
# 597:	learn: 0.0994285	total: 1m 25s	remaining: 57.4s
# 598:	learn: 0.0994184	total: 1m 25s	remaining: 57.2s
# 599:	learn: 0.0993901	total: 1m 25s	remaining: 57.1s
# 600:	learn: 0.0993616	total: 1m 25s	remaining: 56.9s
# 601:	learn: 0.0993464	total: 1m 25s	remaining: 56.8s
# 602:	learn: 0.0993177	total: 1m 26s	remaining: 56.6s
# 603:	learn: 0.0992996	total: 1m 26s	remaining: 56.5s
# 604:	learn: 0.0992965	total: 1m 26s	remaining: 56.3s
# 605:	learn: 0.0992841	total: 1m 26s	remaining: 56.2s
# 606:	learn: 0.0992654	total: 1m 26s	remaining: 56s
# 607:	learn: 0.0992302	total: 1m 26s	remaining: 55.9s
# 608:	learn: 0.0992003	total: 1m 26s	remaining: 55.7s
# 609:	learn: 0.0991838	total: 1m 26s	remaining: 55.6s
# 610:	learn: 0.0991559	total: 1m 27s	remaining: 55.4s
# 611:	learn: 0.0991409	total: 1m 27s	remaining: 55.3s
# 612:	learn: 0.0991171	total: 1m 27s	remaining: 55.1s
# 613:	learn: 0.0991129	total: 1m 27s	remaining: 55s
# 614:	learn: 0.0990732	total: 1m 27s	remaining: 54.8s
# 615:	learn: 0.0990633	total: 1m 27s	remaining: 54.7s
# 616:	learn: 0.0990363	total: 1m 27s	remaining: 54.5s
# 617:	learn: 0.0990286	total: 1m 27s	remaining: 54.4s
# 618:	learn: 0.0990058	total: 1m 28s	remaining: 54.2s
# 619:	learn: 0.0990058	total: 1m 28s	remaining: 54.1s
# 620:	learn: 0.0989920	total: 1m 28s	remaining: 53.9s
# 621:	learn: 0.0989679	total: 1m 28s	remaining: 53.7s
# 622:	learn: 0.0989512	total: 1m 28s	remaining: 53.6s
# 623:	learn: 0.0989276	total: 1m 28s	remaining: 53.5s
# 624:	learn: 0.0989040	total: 1m 28s	remaining: 53.3s
# 625:	learn: 0.0988892	total: 1m 29s	remaining: 53.2s
# 626:	learn: 0.0988689	total: 1m 29s	remaining: 53s
# 627:	learn: 0.0988541	total: 1m 29s	remaining: 52.9s
# 628:	learn: 0.0988441	total: 1m 29s	remaining: 52.8s
# 629:	learn: 0.0988252	total: 1m 29s	remaining: 52.6s
# 630:	learn: 0.0988154	total: 1m 29s	remaining: 52.5s
# 631:	learn: 0.0987865	total: 1m 29s	remaining: 52.3s
# 632:	learn: 0.0987281	total: 1m 29s	remaining: 52.2s
# 633:	learn: 0.0987078	total: 1m 30s	remaining: 52s
# 634:	learn: 0.0986662	total: 1m 30s	remaining: 51.9s
# 635:	learn: 0.0986586	total: 1m 30s	remaining: 51.8s
# 728:	learn: 0.0974225	total: 1m 42s	remaining: 38.3s
# 729:	learn: 0.0974191	total: 1m 43s	remaining: 38.1s
# 730:	learn: 0.0973995	total: 1m 43s	remaining: 38s
# 731:	learn: 0.0973965	total: 1m 43s	remaining: 37.8s
# 732:	learn: 0.0973748	total: 1m 43s	remaining: 37.7s
# 733:	learn: 0.0973640	total: 1m 43s	remaining: 37.5s
# 734:	learn: 0.0973496	total: 1m 43s	remaining: 37.4s
# 735:	learn: 0.0973316	total: 1m 43s	remaining: 37.3s
# 736:	learn: 0.0973256	total: 1m 44s	remaining: 37.1s
# 737:	learn: 0.0973031	total: 1m 44s	remaining: 37s
# 738:	learn: 0.0973002	total: 1m 44s	remaining: 36.8s
# 739:	learn: 0.0972801	total: 1m 44s	remaining: 36.7s
# 740:	learn: 0.0972578	total: 1m 44s	remaining: 36.5s
# 741:	learn: 0.0972360	total: 1m 44s	remaining: 36.4s
# 742:	learn: 0.0972208	total: 1m 44s	remaining: 36.3s
# 743:	learn: 0.0972092	total: 1m 44s	remaining: 36.1s
# 744:	learn: 0.0971946	total: 1m 45s	remaining: 36s
# 745:	learn: 0.0971945	total: 1m 45s	remaining: 35.9s
# 746:	learn: 0.0971594	total: 1m 45s	remaining: 35.7s
# 747:	learn: 0.0971352	total: 1m 45s	remaining: 35.6s
# 748:	learn: 0.0971183	total: 1m 45s	remaining: 35.4s
# 749:	learn: 0.0971002	total: 1m 45s	remaining: 35.3s
# 750:	learn: 0.0970866	total: 1m 46s	remaining: 35.1s
# 751:	learn: 0.0970623	total: 1m 46s	remaining: 35s
# 752:	learn: 0.0970491	total: 1m 46s	remaining: 34.9s
# 753:	learn: 0.0970352	total: 1m 46s	remaining: 34.7s
# 754:	learn: 0.0970259	total: 1m 46s	remaining: 34.6s
# 755:	learn: 0.0970131	total: 1m 46s	remaining: 34.4s
# 756:	learn: 0.0970050	total: 1m 46s	remaining: 34.3s
# 757:	learn: 0.0969857	total: 1m 46s	remaining: 34.1s
# 758:	learn: 0.0969649	total: 1m 47s	remaining: 34s
# 759:	learn: 0.0969516	total: 1m 47s	remaining: 33.9s
# 760:	learn: 0.0969417	total: 1m 47s	remaining: 33.7s
# 761:	learn: 0.0969413	total: 1m 47s	remaining: 33.6s
# 762:	learn: 0.0969363	total: 1m 47s	remaining: 33.4s
# 763:	learn: 0.0969353	total: 1m 47s	remaining: 33.3s
# 764:	learn: 0.0969329	total: 1m 47s	remaining: 33.1s
# 765:	learn: 0.0969172	total: 1m 48s	remaining: 33s
# 766:	learn: 0.0969057	total: 1m 48s	remaining: 32.8s
# 767:	learn: 0.0968961	total: 1m 48s	remaining: 32.7s
# 768:	learn: 0.0968775	total: 1m 48s	remaining: 32.5s
# 769:	learn: 0.0968616	total: 1m 48s	remaining: 32.4s
# 770:	learn: 0.0968522	total: 1m 48s	remaining: 32.3s
# 771:	learn: 0.0968274	total: 1m 48s	remaining: 32.1s
# 772:	learn: 0.0968190	total: 1m 48s	remaining: 32s
# 773:	learn: 0.0968124	total: 1m 49s	remaining: 31.8s
# 774:	learn: 0.0967991	total: 1m 49s	remaining: 31.7s
# 775:	learn: 0.0967885	total: 1m 49s	remaining: 31.5s
# 776:	learn: 0.0967777	total: 1m 49s	remaining: 31.4s
# 777:	learn: 0.0967639	total: 1m 49s	remaining: 31.3s
# 778:	learn: 0.0967338	total: 1m 49s	remaining: 31.1s
# 779:	learn: 0.0967107	total: 1m 49s	remaining: 31s
# 780:	learn: 0.0967031	total: 1m 49s	remaining: 30.8s
# 781:	learn: 0.0966787	total: 1m 50s	remaining: 30.7s
# 782:	learn: 0.0966787	total: 1m 50s	remaining: 30.6s
# 783:	learn: 0.0966722	total: 1m 50s	remaining: 30.4s
# 784:	learn: 0.0966639	total: 1m 50s	remaining: 30.3s
# 785:	learn: 0.0966548	total: 1m 50s	remaining: 30.1s
# 786:	learn: 0.0966386	total: 1m 50s	remaining: 30s
# 787:	learn: 0.0966184	total: 1m 51s	remaining: 29.9s
# 788:	learn: 0.0966090	total: 1m 51s	remaining: 29.7s
# 789:	learn: 0.0965780	total: 1m 51s	remaining: 29.6s
# 790:	learn: 0.0965548	total: 1m 51s	remaining: 29.4s
# 791:	learn: 0.0965541	total: 1m 51s	remaining: 29.3s
# 792:	learn: 0.0965535	total: 1m 51s	remaining: 29.2s
# 793:	learn: 0.0965246	total: 1m 51s	remaining: 29s
# 794:	learn: 0.0965085	total: 1m 52s	remaining: 28.9s
# 795:	learn: 0.0964973	total: 1m 52s	remaining: 28.8s
# 796:	learn: 0.0964796	total: 1m 52s	remaining: 28.6s
# 797:	learn: 0.0964520	total: 1m 52s	remaining: 28.5s
# 798:	learn: 0.0964368	total: 1m 52s	remaining: 28.3s
# 799:	learn: 0.0964063	total: 1m 52s	remaining: 28.2s
# 800:	learn: 0.0963794	total: 1m 52s	remaining: 28s
# 801:	learn: 0.0963680	total: 1m 53s	remaining: 27.9s
# 802:	learn: 0.0963678	total: 1m 53s	remaining: 27.8s
# 803:	learn: 0.0963678	total: 1m 53s	remaining: 27.6s
# 804:	learn: 0.0963595	total: 1m 53s	remaining: 27.5s
# 805:	learn: 0.0963443	total: 1m 53s	remaining: 27.3s
# 806:	learn: 0.0963282	total: 1m 53s	remaining: 27.2s
# 807:	learn: 0.0962852	total: 1m 53s	remaining: 27.1s
# 808:	learn: 0.0962674	total: 1m 54s	remaining: 26.9s
# 809:	learn: 0.0962555	total: 1m 54s	remaining: 26.8s
# 810:	learn: 0.0962414	total: 1m 54s	remaining: 26.6s
# 811:	learn: 0.0962284	total: 1m 54s	remaining: 26.5s
# 812:	learn: 0.0962215	total: 1m 54s	remaining: 26.4s
# 813:	learn: 0.0962037	total: 1m 54s	remaining: 26.2s
# 814:	learn: 0.0961999	total: 1m 54s	remaining: 26.1s
# 815:	learn: 0.0961916	total: 1m 55s	remaining: 25.9s
# 816:	learn: 0.0961513	total: 1m 55s	remaining: 25.8s
# 817:	learn: 0.0961370	total: 1m 55s	remaining: 25.7s
# 818:	learn: 0.0961210	total: 1m 55s	remaining: 25.5s
# 819:	learn: 0.0961011	total: 1m 55s	remaining: 25.4s
# 820:	learn: 0.0960504	total: 1m 55s	remaining: 25.2s
# 821:	learn: 0.0960243	total: 1m 55s	remaining: 25.1s
# 822:	learn: 0.0960149	total: 1m 56s	remaining: 24.9s
# 823:	learn: 0.0959926	total: 1m 56s	remaining: 24.8s
# 824:	learn: 0.0959691	total: 1m 56s	remaining: 24.7s
# 825:	learn: 0.0959529	total: 1m 56s	remaining: 24.5s
# 826:	learn: 0.0959360	total: 1m 56s	remaining: 24.4s
# 827:	learn: 0.0959151	total: 1m 56s	remaining: 24.2s
# 828:	learn: 0.0959069	total: 1m 56s	remaining: 24.1s
# 829:	learn: 0.0958703	total: 1m 56s	remaining: 23.9s
# 830:	learn: 0.0958400	total: 1m 57s	remaining: 23.8s
# 831:	learn: 0.0958166	total: 1m 57s	remaining: 23.7s
# 832:	learn: 0.0958147	total: 1m 57s	remaining: 23.5s
# 833:	learn: 0.0958051	total: 1m 57s	remaining: 23.4s
# 834:	learn: 0.0957656	total: 1m 57s	remaining: 23.3s
# 835:	learn: 0.0957083	total: 1m 57s	remaining: 23.1s
# 836:	learn: 0.0956997	total: 1m 57s	remaining: 23s
# 837:	learn: 0.0956796	total: 1m 58s	remaining: 22.8s
# 838:	learn: 0.0956629	total: 1m 58s	remaining: 22.7s
# 839:	learn: 0.0956497	total: 1m 58s	remaining: 22.6s
# 840:	learn: 0.0956394	total: 1m 58s	remaining: 22.4s
# 841:	learn: 0.0956276	total: 1m 58s	remaining: 22.3s
# 842:	learn: 0.0956167	total: 1m 58s	remaining: 22.1s
# 843:	learn: 0.0956102	total: 1m 59s	remaining: 22s
# 844:	learn: 0.0956070	total: 1m 59s	remaining: 21.9s
# 845:	learn: 0.0955982	total: 1m 59s	remaining: 21.7s
# 846:	learn: 0.0955982	total: 1m 59s	remaining: 21.6s
# 847:	learn: 0.0955960	total: 1m 59s	remaining: 21.4s
# 848:	learn: 0.0955832	total: 1m 59s	remaining: 21.3s
# 849:	learn: 0.0955789	total: 1m 59s	remaining: 21.1s
# 850:	learn: 0.0955740	total: 1m 59s	remaining: 21s
# 851:	learn: 0.0955668	total: 2m	remaining: 20.9s
# 852:	learn: 0.0955622	total: 2m	remaining: 20.7s
# 853:	learn: 0.0955622	total: 2m	remaining: 20.6s
# 854:	learn: 0.0955181	total: 2m	remaining: 20.4s
# 855:	learn: 0.0955067	total: 2m	remaining: 20.3s
# 856:	learn: 0.0954993	total: 2m	remaining: 20.2s
# 857:	learn: 0.0954988	total: 2m	remaining: 20s
# 858:	learn: 0.0954847	total: 2m 1s	remaining: 19.9s
# 859:	learn: 0.0954758	total: 2m 1s	remaining: 19.7s
# 860:	learn: 0.0954618	total: 2m 1s	remaining: 19.6s
# 861:	learn: 0.0954459	total: 2m 1s	remaining: 19.5s
# 862:	learn: 0.0954191	total: 2m 1s	remaining: 19.3s
# 863:	learn: 0.0953683	total: 2m 1s	remaining: 19.2s
# 864:	learn: 0.0953482	total: 2m 1s	remaining: 19s
# 865:	learn: 0.0953476	total: 2m 2s	remaining: 18.9s
# 866:	learn: 0.0953367	total: 2m 2s	remaining: 18.8s
# 867:	learn: 0.0953292	total: 2m 2s	remaining: 18.6s
# 868:	learn: 0.0952999	total: 2m 2s	remaining: 18.5s
# 869:	learn: 0.0952817	total: 2m 2s	remaining: 18.3s
# 870:	learn: 0.0952571	total: 2m 2s	remaining: 18.2s
# 871:	learn: 0.0952514	total: 2m 2s	remaining: 18s
# 872:	learn: 0.0952276	total: 2m 3s	remaining: 17.9s
# 873:	learn: 0.0952177	total: 2m 3s	remaining: 17.8s
# 874:	learn: 0.0951744	total: 2m 3s	remaining: 17.6s
# 875:	learn: 0.0951691	total: 2m 3s	remaining: 17.5s
# 876:	learn: 0.0951617	total: 2m 3s	remaining: 17.3s
# 877:	learn: 0.0951518	total: 2m 3s	remaining: 17.2s
# 878:	learn: 0.0951234	total: 2m 3s	remaining: 17.1s
# 879:	learn: 0.0951023	total: 2m 4s	remaining: 16.9s
# 880:	learn: 0.0950916	total: 2m 4s	remaining: 16.8s
# 881:	learn: 0.0950729	total: 2m 4s	remaining: 16.6s
# 882:	learn: 0.0950606	total: 2m 4s	remaining: 16.5s
# 883:	learn: 0.0950363	total: 2m 4s	remaining: 16.4s
# 884:	learn: 0.0949661	total: 2m 4s	remaining: 16.2s
# 885:	learn: 0.0949459	total: 2m 4s	remaining: 16.1s
# 886:	learn: 0.0949377	total: 2m 5s	remaining: 15.9s
# 887:	learn: 0.0949202	total: 2m 5s	remaining: 15.8s
# 888:	learn: 0.0949047	total: 2m 5s	remaining: 15.7s
# 889:	learn: 0.0948978	total: 2m 5s	remaining: 15.5s
# 890:	learn: 0.0948816	total: 2m 5s	remaining: 15.4s
# 891:	learn: 0.0948544	total: 2m 5s	remaining: 15.2s
# 892:	learn: 0.0948431	total: 2m 5s	remaining: 15.1s
# 893:	learn: 0.0948430	total: 2m 6s	remaining: 14.9s
# 894:	learn: 0.0948341	total: 2m 6s	remaining: 14.8s
# 895:	learn: 0.0948060	total: 2m 6s	remaining: 14.7s
# 896:	learn: 0.0948036	total: 2m 6s	remaining: 14.5s
# 897:	learn: 0.0947665	total: 2m 6s	remaining: 14.4s
# 898:	learn: 0.0947638	total: 2m 6s	remaining: 14.2s
# 899:	learn: 0.0947420	total: 2m 6s	remaining: 14.1s
# 900:	learn: 0.0947392	total: 2m 7s	remaining: 14s
# 901:	learn: 0.0947290	total: 2m 7s	remaining: 13.8s
# 902:	learn: 0.0947057	total: 2m 7s	remaining: 13.7s
# 903:	learn: 0.0946988	total: 2m 7s	remaining: 13.5s
# 904:	learn: 0.0946963	total: 2m 7s	remaining: 13.4s
# 905:	learn: 0.0946900	total: 2m 7s	remaining: 13.3s
# 906:	learn: 0.0946746	total: 2m 7s	remaining: 13.1s
# 907:	learn: 0.0946653	total: 2m 8s	remaining: 13s
# 908:	learn: 0.0946624	total: 2m 8s	remaining: 12.8s
# 909:	learn: 0.0946302	total: 2m 8s	remaining: 12.7s
# 910:	learn: 0.0946267	total: 2m 8s	remaining: 12.6s
# 911:	learn: 0.0946035	total: 2m 8s	remaining: 12.4s
# 912:	learn: 0.0945921	total: 2m 8s	remaining: 12.3s
# 960:	learn: 0.0940361	total: 2m 15s	remaining: 5.5s
# 961:	learn: 0.0940305	total: 2m 15s	remaining: 5.36s
# 962:	learn: 0.0940301	total: 2m 15s	remaining: 5.21s
# 963:	learn: 0.0940208	total: 2m 15s	remaining: 5.07s
# 964:	learn: 0.0940076	total: 2m 16s	remaining: 4.93s
# 965:	learn: 0.0939953	total: 2m 16s	remaining: 4.79s
# 966:	learn: 0.0939866	total: 2m 16s	remaining: 4.65s
# 967:	learn: 0.0939771	total: 2m 16s	remaining: 4.51s
# 968:	learn: 0.0939594	total: 2m 16s	remaining: 4.37s
# 969:	learn: 0.0939484	total: 2m 16s	remaining: 4.23s
# 970:	learn: 0.0939189	total: 2m 16s	remaining: 4.09s
# 971:	learn: 0.0939188	total: 2m 17s	remaining: 3.95s
# 972:	learn: 0.0939086	total: 2m 17s	remaining: 3.8s
# 973:	learn: 0.0939085	total: 2m 17s	remaining: 3.66s
# 974:	learn: 0.0939085	total: 2m 17s	remaining: 3.52s
# 975:	learn: 0.0939083	total: 2m 17s	remaining: 3.38s
# 976:	learn: 0.0938942	total: 2m 17s	remaining: 3.24s
# 977:	learn: 0.0938942	total: 2m 17s	remaining: 3.1s
# 978:	learn: 0.0938941	total: 2m 17s	remaining: 2.96s
# 979:	learn: 0.0938886	total: 2m 17s	remaining: 2.81s
# 980:	learn: 0.0938833	total: 2m 18s	remaining: 2.67s
# 981:	learn: 0.0938731	total: 2m 18s	remaining: 2.53s
# 982:	learn: 0.0938705	total: 2m 18s	remaining: 2.39s
# 983:	learn: 0.0938608	total: 2m 18s	remaining: 2.25s
# 984:	learn: 0.0938230	total: 2m 18s	remaining: 2.11s
# 985:	learn: 0.0938026	total: 2m 18s	remaining: 1.97s
# 986:	learn: 0.0937953	total: 2m 18s	remaining: 1.83s
# 987:	learn: 0.0937875	total: 2m 19s	remaining: 1.69s
# 988:	learn: 0.0937748	total: 2m 19s	remaining: 1.55s
# 989:	learn: 0.0937676	total: 2m 19s	remaining: 1.41s
# 990:	learn: 0.0937436	total: 2m 19s	remaining: 1.27s
# 991:	learn: 0.0937284	total: 2m 19s	remaining: 1.13s
# 992:	learn: 0.0937158	total: 2m 19s	remaining: 986ms
# 993:	learn: 0.0937074	total: 2m 19s	remaining: 845ms
# 994:	learn: 0.0936962	total: 2m 20s	remaining: 704ms
# 995:	learn: 0.0936806	total: 2m 20s	remaining: 563ms
# 996:	learn: 0.0936777	total: 2m 20s	remaining: 423ms
# 997:	learn: 0.0936715	total: 2m 20s	remaining: 282ms
# 998:	learn: 0.0936561	total: 2m 20s	remaining: 141ms
# 999:	learn: 0.0936462	total: 2m 20s	remaining: 0us

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy : {accuracy}')
# Out:
# Accuracy : 0.9651556156968877

# %%
f1_macro = f1_score(y_test, y_pred, average="macro")

print(f"Score F1 : {f1_macro}")
# Out:
# Score F1 : 0.9328690780776092

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.86      0.89      2794
#            1       0.97      0.98      0.98     14942
#
#     accuracy                           0.97     17736
#    macro avg       0.94      0.92      0.93     17736
# weighted avg       0.96      0.97      0.96     17736
