# %% [markdown]
# # EDA sur le jeu de données de la SBA

# %%
import os
import sys
import gdown
import shutil

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('SBAcleaned.csv')

# %%
correlation_figure, correlation_axis = plt.subplots(figsize = (30,25))
corr_mat = df.corr()
correlation_axis = sns.heatmap(corr_mat, annot= True)

plt.xticks(rotation = 30, horizontalalignment = 'right', fontsize = 20)
plt.yticks(fontsize = 20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 correlation_figure, correlation_axis = plt.subplots(figsize = (30,25))
# ----> 2 corr_mtrx = df.corr()
#       3 correlation_axis = sns.heatmap(corr_mtrx, annot= True)
#       5 plt.xticks(rotation = 30, horizontalalignment = 'right', fontsize = 20)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:11022, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11020 cols = data.columns
#   11021 idx = cols.copy()
# > 11022 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11024 if method == "pearson":
#   11025     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# ...
